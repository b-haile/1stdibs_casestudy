# %% [markdown]
# ## This notebook is for exploration of the worksheets provided, and is not the final product of the assignment.

# %%
import pandas as pd
import datetime
import numpy as np

# %%
dib1 = pd.read_csv("Worksheets/dib1.csv")
dib1
# Out:
#          id seller_pk seller_status seller_status_code seller_rating  \
# 0         2       f_2        closed   closed.voluntary           NaN
# 1         3       f_3        closed   closed.voluntary           NaN
# 2         4       f_4        closed   closed.voluntary           NaN
# 3         5       f_5        closed   closed.voluntary           NaN
# 4         6       f_6        closed   closed.voluntary           NaN
# ...     ...       ...           ...                ...           ...
# 7391  55832   f_55832       pending        pending.new        C_PLUS
# 7392  55842   f_55842       pending        pending.new             B
# 7393  55852   f_55852       pending     pending.unpaid             B
# 7394  55862   f_55862       pending     pending.unpaid             C
# 7395  55872   f_55872       pending        pending.new        B_PLUS
#
#       seller_date_registered  seller_date_contract_start seller_distinguished  \
# 0               1.002673e+09                0.000000e+00                  NaN
# 1               9.681887e+08                0.000000e+00                  NaN
# 2               9.681889e+08                0.000000e+00                  NaN
# 3               9.681890e+08                0.000000e+00                  NaN
# 4               9.681890e+08                0.000000e+00                  NaN
# ...                      ...                         ...                  ...
# 7391            1.610576e+09                1.610428e+09                  NaN
# 7392            1.610640e+09                1.610514e+09                  NaN
# 7393            1.610640e+09                1.610514e+09                  NaN
# 7394            1.610643e+09                1.610514e+09                  NaN
# 7395            1.610644e+09                1.609996e+09                  NaN
#
#       Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0            NaN         NaN  ...          NaN          NaN          NaN
# 1            NaN         NaN  ...          NaN          NaN          NaN
# 2            NaN         NaN  ...          NaN          NaN          NaN
# 3            NaN         NaN  ...          NaN          NaN          NaN
# 4            NaN         NaN  ...          NaN          NaN          NaN
# ...          ...         ...  ...          ...          ...          ...
# 7391         NaN         NaN  ...          NaN          NaN          NaN
# 7392         NaN         NaN  ...          NaN          NaN          NaN
# 7393         NaN         NaN  ...          NaN          NaN          NaN
# 7394         NaN         NaN  ...          NaN          NaN          NaN
# 7395         NaN         NaN  ...          NaN          NaN          NaN
#
#       Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0             NaN          NaN          NaN          NaN          NaN
# 1             NaN          NaN          NaN          NaN          NaN
# 2             NaN          NaN          NaN          NaN          NaN
# 3             NaN          NaN          NaN          NaN          NaN
# 4             NaN          NaN          NaN          NaN          NaN
# ...           ...          ...          ...          ...          ...
# 7391          NaN          NaN          NaN          NaN          NaN
# 7392          NaN          NaN          NaN          NaN          NaN
# 7393          NaN          NaN          NaN          NaN          NaN
# 7394          NaN          NaN          NaN          NaN          NaN
# 7395          NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 24  Unnamed: 25
# 0             NaN          NaN
# 1             NaN          NaN
# 2             NaN          NaN
# 3             NaN          NaN
# 4             NaN          NaN
# ...           ...          ...
# 7391          NaN          NaN
# 7392          NaN          NaN
# 7393          NaN          NaN
# 7394          NaN          NaN
# 7395          NaN          NaN
#
# [7396 rows x 26 columns]

# %%
dib1.columns
# Out:
# Index(['id', 'seller_pk', 'seller_status', 'seller_status_code',
#        'seller_rating', 'seller_date_registered', 'seller_date_contract_start',
#        'seller_distinguished', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
dib1 = dib1.drop(['Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
       'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
       'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
       'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1)
dib1.head()
# Out:
#    id seller_pk seller_status seller_status_code seller_rating  \
# 0   2       f_2        closed   closed.voluntary           NaN
# 1   3       f_3        closed   closed.voluntary           NaN
# 2   4       f_4        closed   closed.voluntary           NaN
# 3   5       f_5        closed   closed.voluntary           NaN
# 4   6       f_6        closed   closed.voluntary           NaN
#
#    seller_date_registered  seller_date_contract_start seller_distinguished
# 0            1.002673e+09                         0.0                  NaN
# 1            9.681887e+08                         0.0                  NaN
# 2            9.681889e+08                         0.0                  NaN
# 3            9.681890e+08                         0.0                  NaN
# 4            9.681890e+08                         0.0                  NaN

# %%
a_r = pd.read_csv("Worksheets/account_records.csv")
a_r.columns
# Out:
# Index(['id', 'seller_pk', 'account_id', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
a_r = a_r.drop(['Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
       'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
       'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
       'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1)
a_r.head()
# Out:
#    id seller_pk          account_id
# 0   3   f_10528  0010L00001jCjRGQA0
# 1  23   f_11082  0010L00001jlT9DQAU
# 2  43     a_249  001E000000gTjMYIA0
# 3  63     a_330  001E000000kd4uaIAA
# 4  83    a_4853  0010L00001idalvQAA

# %%
dib1.shape
# Out:
# (7396, 8)

# %%
a_r.shape
# Out:
# (10488, 3)

# %%
df = pd.merge(dib1, a_r.drop(['id'], axis=1), on='seller_pk')
df.head()
# Out:
#    id seller_pk seller_status seller_status_code seller_rating  \
# 0   2       f_2        closed   closed.voluntary           NaN
# 1   3       f_3        closed   closed.voluntary           NaN
# 2   7       f_7        closed   closed.voluntary           NaN
# 3   8       f_8        closed   closed.voluntary           NaN
# 4   9       f_9        closed   closed.voluntary           NaN
#
#    seller_date_registered  seller_date_contract_start seller_distinguished  \
# 0            1.002673e+09                         0.0                  NaN
# 1            9.681887e+08                         0.0                  NaN
# 2            9.681891e+08                         0.0                  NaN
# 3            9.681892e+08                         0.0                  NaN
# 4            9.681892e+08                         0.0                  NaN
#
#            account_id
# 0  001E000000DwI2OIAV
# 1  001E000000DwI2PIAV
# 2  001E000000DwI2SIAV
# 3  001E000000DwI2TIAV
# 4  001E000000DwI2UIAV

# %%
df.shape
# Out:
# (6520, 9)

# %%
c_r = pd.read_csv("Worksheets/contact_records.csv")
c_r = c_r.drop(['Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
       'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
       'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
       'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1)
c_r.head()
# Out:
#    id seller_pk          contact_id
# 0  13   f_10528  0030L00001l22bUQAQ
# 1  33   f_11082  0030L00001l3YfJQAU
# 2  53     a_249  003E000001dzO67IAE
# 3  73     a_330  0030L00001l11ShQAI
# 4  93    a_4853  0030L00001jYzELQA0

# %%
c_r.shape
# Out:
# (10488, 3)

# %%
df = pd.merge(df, c_r.drop(['id'], axis=1), on='seller_pk')
df.head()
# Out:
#    id seller_pk seller_status seller_status_code seller_rating  \
# 0   2       f_2        closed   closed.voluntary           NaN
# 1   3       f_3        closed   closed.voluntary           NaN
# 2   7       f_7        closed   closed.voluntary           NaN
# 3   8       f_8        closed   closed.voluntary           NaN
# 4   9       f_9        closed   closed.voluntary           NaN
#
#    seller_date_registered  seller_date_contract_start seller_distinguished  \
# 0            1.002673e+09                         0.0                  NaN
# 1            9.681887e+08                         0.0                  NaN
# 2            9.681891e+08                         0.0                  NaN
# 3            9.681892e+08                         0.0                  NaN
# 4            9.681892e+08                         0.0                  NaN
#
#            account_id          contact_id
# 0  001E000000DwI2OIAV  003E000000ABxThIAL
# 1  001E000000DwI2PIAV  003E000000ABxTiIAL
# 2  001E000000DwI2SIAV  003E000000ABxTlIAL
# 3  001E000000DwI2TIAV  003E000000ABxTmIAL
# 4  001E000000DwI2UIAV  003E000000ABxTnIAL

# %%
df.shape
# Out:
# (6520, 10)

# %%
ad = pd.read_csv("Worksheets/addresses.csv")
ad = ad.drop(['Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
       'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
       'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
       'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1)
ad.head()
# Out:
#          id  state country
# 0  56704683  Paris      FR
# 1  56704683  Paris      FR
# 2  56704953     NY      US
# 3  56704953     NY      US
# 4  56777063     NY      US

# %%
adxref = pd.read_csv("Worksheets/addresses_xref.csv")
adxref = adxref.drop(['Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
       'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
       'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
       'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1)
adxref.head()
# Out:
#          id seller_pk  address_id address_status     address_type
# 0  39554703       a_0    56831853         ACTIVE  SELLER_SHIPPING
# 1  39554723       a_0    56831853         ACTIVE   SELLER_DEFAULT
# 2  39349933       a_1    56704683         ACTIVE  SELLER_SHIPPING
# 3  39349993       a_1    56704683         ACTIVE   SELLER_DEFAULT
# 4  39350743      a_10    56704953         ACTIVE  SELLER_SHIPPING

# %%
adds = pd.merge(ad, adxref, left_on='id', right_on='address_id', how='outer')
adds.head()
# Out:
#          id_x  state country      id_y seller_pk  address_id address_status  \
# 0  56704683.0  Paris      FR  39349933       a_1    56704683         ACTIVE
# 1  56704683.0  Paris      FR  39349993       a_1    56704683         ACTIVE
# 2  56704683.0  Paris      FR  39349933       a_1    56704683         ACTIVE
# 3  56704683.0  Paris      FR  39349993       a_1    56704683         ACTIVE
# 4  56704953.0     NY      US  39350743      a_10    56704953         ACTIVE
#
#       address_type
# 0  SELLER_SHIPPING
# 1   SELLER_DEFAULT
# 2  SELLER_SHIPPING
# 3   SELLER_DEFAULT
# 4  SELLER_SHIPPING

# %%
adds.drop(['id_x', 'id_y'], axis=1, inplace=True)
adds.head()
# Out:
#    state country seller_pk  address_id address_status     address_type
# 0  Paris      FR       a_1    56704683         ACTIVE  SELLER_SHIPPING
# 1  Paris      FR       a_1    56704683         ACTIVE   SELLER_DEFAULT
# 2  Paris      FR       a_1    56704683         ACTIVE  SELLER_SHIPPING
# 3  Paris      FR       a_1    56704683         ACTIVE   SELLER_DEFAULT
# 4     NY      US      a_10    56704953         ACTIVE  SELLER_SHIPPING

# %%
ff = pd.merge(df, adds, on='seller_pk')
ff.head()
# Out:
#    id seller_pk seller_status seller_status_code seller_rating  \
# 0   2       f_2        closed   closed.voluntary           NaN
# 1   2       f_2        closed   closed.voluntary           NaN
# 2   2       f_2        closed   closed.voluntary           NaN
# 3   2       f_2        closed   closed.voluntary           NaN
# 4   3       f_3        closed   closed.voluntary           NaN
#
#    seller_date_registered  seller_date_contract_start seller_distinguished  \
# 0            1.002673e+09                         0.0                  NaN
# 1            1.002673e+09                         0.0                  NaN
# 2            1.002673e+09                         0.0                  NaN
# 3            1.002673e+09                         0.0                  NaN
# 4            9.681887e+08                         0.0                  NaN
#
#            account_id          contact_id  state country  address_id  \
# 0  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 1  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 2  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 3  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 4  001E000000DwI2PIAV  003E000000ABxTiIAL  Paris      FR    56682833
#
#   address_status     address_type
# 0         ACTIVE  SELLER_SHIPPING
# 1         ACTIVE   SELLER_DEFAULT
# 2         ACTIVE  SELLER_SHIPPING
# 3         ACTIVE   SELLER_DEFAULT
# 4         ACTIVE  SELLER_SHIPPING

# %%
ff.shape
# Out:
# (31598, 15)

# %%
ff['seller_status_code'] = ff.seller_status_code.str.replace('.', ' - ')
ff['seller_status_code'] = ff.seller_status_code.str.title()
ff['seller_status'] = ff.seller_status.str.title()
ff.head()
# Out:
#    id seller_pk seller_status  seller_status_code seller_rating  \
# 0   2       f_2        Closed  Closed - Voluntary           NaN
# 1   2       f_2        Closed  Closed - Voluntary           NaN
# 2   2       f_2        Closed  Closed - Voluntary           NaN
# 3   2       f_2        Closed  Closed - Voluntary           NaN
# 4   3       f_3        Closed  Closed - Voluntary           NaN
#
#    seller_date_registered  seller_date_contract_start seller_distinguished  \
# 0            1.002673e+09                         0.0                  NaN
# 1            1.002673e+09                         0.0                  NaN
# 2            1.002673e+09                         0.0                  NaN
# 3            1.002673e+09                         0.0                  NaN
# 4            9.681887e+08                         0.0                  NaN
#
#            account_id          contact_id  state country  address_id  \
# 0  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 1  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 2  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 3  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 4  001E000000DwI2PIAV  003E000000ABxTiIAL  Paris      FR    56682833
#
#   address_status     address_type
# 0         ACTIVE  SELLER_SHIPPING
# 1         ACTIVE   SELLER_DEFAULT
# 2         ACTIVE  SELLER_SHIPPING
# 3         ACTIVE   SELLER_DEFAULT
# 4         ACTIVE  SELLER_SHIPPING

# %%
ff['seller_distinguished'].fillna(0, inplace=True)
ff['seller_distinguished'].replace('DISTINGUISHED', 1, inplace=True)
ff.head()
# Out:
#    id seller_pk seller_status  seller_status_code seller_rating  \
# 0   2       f_2        Closed  Closed - Voluntary           NaN
# 1   2       f_2        Closed  Closed - Voluntary           NaN
# 2   2       f_2        Closed  Closed - Voluntary           NaN
# 3   2       f_2        Closed  Closed - Voluntary           NaN
# 4   3       f_3        Closed  Closed - Voluntary           NaN
#
#    seller_date_registered  seller_date_contract_start  seller_distinguished  \
# 0            1.002673e+09                         0.0                     0
# 1            1.002673e+09                         0.0                     0
# 2            1.002673e+09                         0.0                     0
# 3            1.002673e+09                         0.0                     0
# 4            9.681887e+08                         0.0                     0
#
#            account_id          contact_id  state country  address_id  \
# 0  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 1  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 2  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 3  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 4  001E000000DwI2PIAV  003E000000ABxTiIAL  Paris      FR    56682833
#
#   address_status     address_type
# 0         ACTIVE  SELLER_SHIPPING
# 1         ACTIVE   SELLER_DEFAULT
# 2         ACTIVE  SELLER_SHIPPING
# 3         ACTIVE   SELLER_DEFAULT
# 4         ACTIVE  SELLER_SHIPPING

# %%
ff['seller_distinguished'].value_counts()
# Out:
# 0    30392
# 1     1206
# Name: seller_distinguished, dtype: int64

# %%
# ff['seller_date_contract_start'] = ff['seller_date_contract_start'].replace(0, np.nan)

# %%
ff['seller_date_registered'] = ff['seller_date_registered'].astype(int)
ff['seller_date_contract_start'] = ff['seller_date_contract_start'].astype(int)

# %%
ff['seller_date_registered'] = pd.to_datetime(ff['seller_date_registered'], unit='s')
ff['seller_date_contract_start'] = pd.to_datetime(ff['seller_date_contract_start'], unit='s')
# ff['seller_date_contract_start'] = pd.to_datetime(df['seller_date_contract_start'], unit='s')

# %%
ff['seller_date_contract_start'] = ff['seller_date_contract_start'].replace('1970-1-1 0:0:0', np.nan)

# %%
ff.head()
# Out:
#    id seller_pk seller_status  seller_status_code seller_rating  \
# 0   2       f_2        Closed  Closed - Voluntary           NaN
# 1   2       f_2        Closed  Closed - Voluntary           NaN
# 2   2       f_2        Closed  Closed - Voluntary           NaN
# 3   2       f_2        Closed  Closed - Voluntary           NaN
# 4   3       f_3        Closed  Closed - Voluntary           NaN
#
#   seller_date_registered seller_date_contract_start  seller_distinguished  \
# 0    2001-10-10 00:12:55                 1970-01-01                     0
# 1    2001-10-10 00:12:55                 1970-01-01                     0
# 2    2001-10-10 00:12:55                 1970-01-01                     0
# 3    2001-10-10 00:12:55                 1970-01-01                     0
# 4    2000-09-05 21:19:04                 1970-01-01                     0
#
#            account_id          contact_id  state country  address_id  \
# 0  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 1  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 2  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 3  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 4  001E000000DwI2PIAV  003E000000ABxTiIAL  Paris      FR    56682833
#
#   address_status     address_type
# 0         ACTIVE  SELLER_SHIPPING
# 1         ACTIVE   SELLER_DEFAULT
# 2         ACTIVE  SELLER_SHIPPING
# 3         ACTIVE   SELLER_DEFAULT
# 4         ACTIVE  SELLER_SHIPPING

# %%
ff['seller_date_registered'].dtype
# Out:
# dtype('<M8[ns]')

# %%
ff['seller_date_contract_start'] = ff['seller_date_contract_start'].replace('1970-01-01', 'NA')

# %%
ff.head()
# Out:
#    id seller_pk seller_status  seller_status_code seller_rating  \
# 0   2       f_2        Closed  Closed - Voluntary           NaN
# 1   2       f_2        Closed  Closed - Voluntary           NaN
# 2   2       f_2        Closed  Closed - Voluntary           NaN
# 3   2       f_2        Closed  Closed - Voluntary           NaN
# 4   3       f_3        Closed  Closed - Voluntary           NaN
#
#   seller_date_registered seller_date_contract_start  seller_distinguished  \
# 0    2001-10-10 00:12:55                 1970-01-01                     0
# 1    2001-10-10 00:12:55                 1970-01-01                     0
# 2    2001-10-10 00:12:55                 1970-01-01                     0
# 3    2001-10-10 00:12:55                 1970-01-01                     0
# 4    2000-09-05 21:19:04                 1970-01-01                     0
#
#            account_id          contact_id  state country  address_id  \
# 0  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 1  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 2  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 3  001E000000DwI2OIAV  003E000000ABxThIAL    NaN      FR    56682823
# 4  001E000000DwI2PIAV  003E000000ABxTiIAL  Paris      FR    56682833
#
#   address_status     address_type
# 0         ACTIVE  SELLER_SHIPPING
# 1         ACTIVE   SELLER_DEFAULT
# 2         ACTIVE  SELLER_SHIPPING
# 3         ACTIVE   SELLER_DEFAULT
# 4         ACTIVE  SELLER_SHIPPING

# %%
ff['seller_date_registered'] = ff['seller_date_registered'].astype('datetime64')

# %%
ff['seller_date_contract_start'].tail()
# Out:
# 31593   2021-01-13 05:00:00
# 31594   2021-01-13 05:00:00
# 31595   2021-01-07 05:00:00
# 31596   2021-01-07 05:00:00
# 31597   2021-01-07 05:00:00
# Name: seller_date_contract_start, dtype: datetime64[ns]

# %%
df1 = pd.concat([ff['state'], ff['country'], ff['address_type']], axis=1)
df1.head()
# Out:
#    state country     address_type
# 0    NaN      FR  SELLER_SHIPPING
# 1    NaN      FR   SELLER_DEFAULT
# 2    NaN      FR  SELLER_SHIPPING
# 3    NaN      FR   SELLER_DEFAULT
# 4  Paris      FR  SELLER_SHIPPING

# %%
df2 = df1.pivot(columns='address_type')
df2.head()
# Out:
#                       state                                            \
# address_type SELLER_BILLING SELLER_DEFAULT SELLER_PAY SELLER_SHIPPING
# 0                       NaN            NaN        NaN             NaN
# 1                       NaN            NaN        NaN             NaN
# 2                       NaN            NaN        NaN             NaN
# 3                       NaN            NaN        NaN             NaN
# 4                       NaN            NaN        NaN           Paris
#
#                     country
# address_type SELLER_BILLING SELLER_DEFAULT SELLER_PAY SELLER_SHIPPING
# 0                       NaN            NaN        NaN              FR
# 1                       NaN             FR        NaN             NaN
# 2                       NaN            NaN        NaN              FR
# 3                       NaN             FR        NaN             NaN
# 4                       NaN            NaN        NaN              FR

# %%
newf = a.pivot(index='col1', columns='col2')
